# %%
import pandas as pd

df = pd.read_csv('final_project_data.csv')

for index, row in df.iterrows():
    print(f"{row['name']} & \cellcolor[HTML]{{FFFFFF}}{row['classes']} & \cellcolor[HTML]{{FFFFFF}}{row['stars']} & {round(row['CHM'],2)} & {round(row['CHD'],2)} & {round(row['IFN'],2)} & {round(row['CMQ'],2)} & {round(row['SMQ'],2)} & {int(row['SERVICES'])}\\\ \hline")
# Out:
# miansen/Roothub & \cellcolor[HTML]{FFFFFF}389 & \cellcolor[HTML]{FFFFFF}100 & 0.31 & 0.34 & 1.61 & 0.37 & 0.14 & 34\\ \hline
# huanglu20124/invoice & \cellcolor[HTML]{FFFFFF}73 & \cellcolor[HTML]{FFFFFF}95 & 0.69 & 0.55 & 1.0 & 0.28 & 0.14 & 9\\ \hline
# Lab41/Dendrite & \cellcolor[HTML]{FFFFFF}101 & \cellcolor[HTML]{FFFFFF}92 & 0.56 & 0.7 & 1.2 & 0.49 & 0.19 & 21\\ \hline
# pibigstar/parsevip & \cellcolor[HTML]{FFFFFF}90 & \cellcolor[HTML]{FFFFFF}87 & 0.76 & 0.43 & 1.36 & 0.22 & 0.38 & 15\\ \hline
# OCR4all/OCR4all & \cellcolor[HTML]{FFFFFF}47 & \cellcolor[HTML]{FFFFFF}86 & 0.81 & 0.99 & 1.27 & 0.64 & 0.26 & 16\\ \hline
# moocss/EasyCMS & \cellcolor[HTML]{FFFFFF}64 & \cellcolor[HTML]{FFFFFF}86 & 0.73 & 0.97 & 1.25 & 0.42 & 0.19 & 10\\ \hline
# Vino007/javaEEScaffold & \cellcolor[HTML]{FFFFFF}45 & \cellcolor[HTML]{FFFFFF}84 & 0.51 & 0.25 & 1.75 & 0.31 & 0.21 & 11\\ \hline
# ...
